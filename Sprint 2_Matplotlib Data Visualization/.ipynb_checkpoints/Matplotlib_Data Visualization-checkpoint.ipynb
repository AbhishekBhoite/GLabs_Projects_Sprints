# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data
df = pd.read_csv(r"C:\Users\vaibh\Desktop\Python DS\Sprint 2_Matplotlib Data Visualization\file (1).csv")
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
# reset index to 'Name'
df.set_index('Name', inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
# drop column '#'
df.drop('#', inplace=True, axis=1)
df.head()
# Out:
#               Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      Grass  Poison  45      49       49       65       65     45
# Ivysaur        Grass  Poison  60      62       63       80       80     60
# Venusaur       Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# Charmander      Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
#3.1.2 Bar-chart and Anatomy of a Plot

# Counts for 'Type 2' counts in descending order
type_2=df['Type 2'].value_counts(ascending=False)
plt.figure(figsize=[14,8])
plt.xlabel("Type 2 Pokemon Variants")
plt.ylabel("No of Pokemons")
# title the plot
plt.title("Distribution of pokemon across various Type 2 variants")
# bar chart
plt.bar(type_2.index,type_2)
# Out:
# <BarContainer object of 18 artists>

# %%
#From the pandas dataframe itself, you can call the plot function and plot the same data
df['Type 2'].value_counts().plot(kind="bar")

# %%
#3.1.3 Line Plots and Plot Customizations
# How does the mean attack points (`Attack`) for `Type 1` Pokemons fare against `Type 2`?

# Type 1 mean attack points dataframe for every category
type_1= df.groupby(['Type 1'])[['Attack']].mean()
type_1
# Out:
#               Attack
# Type 1
# Bug        70.971014
# Dark       88.387097
# Dragon    112.125000
# Electric   69.090909
# Fairy      61.529412
# Fighting   96.777778
# Fire       84.769231
# Flying     78.750000
# Ghost      73.781250
# Grass      73.214286
# Ground     95.750000
# Ice        72.750000
# Normal     73.469388
# Poison     74.678571
# Psychic    71.456140
# Rock       92.863636
# Steel      92.703704
# Water      74.151786

# %%
# Type 2 mean attack points dataframe for every category
type_2= df.groupby(['Type 2'])[['Attack']].mean()
type_2
# Out:
#               Attack
# Type 2
# Bug        90.000000
# Dark      109.800000
# Dragon     94.444444
# Electric   72.666667
# Fairy      61.608696
# Fighting  112.846154
# Fire       81.250000
# Flying     80.288660
# Ghost      84.142857
# Grass      74.160000
# Ground     89.857143
# Ice        98.000000
# Normal     52.750000
# Poison     67.588235
# Psychic    74.696970
# Rock       84.000000
# Steel      92.590909
# Water      70.142857

# %%
# Reset index for both type_1 dataframe
type_1.reset_index(inplace=True)
type_1
# Out:
#       Type 1      Attack
# 0        Bug   70.971014
# 1       Dark   88.387097
# 2     Dragon  112.125000
# 3   Electric   69.090909
# 4      Fairy   61.529412
# 5   Fighting   96.777778
# 6       Fire   84.769231
# 7     Flying   78.750000
# 8      Ghost   73.781250
# 9      Grass   73.214286
# 10    Ground   95.750000
# 11       Ice   72.750000
# 12    Normal   73.469388
# 13    Poison   74.678571
# 14   Psychic   71.456140
# 15      Rock   92.863636
# 16     Steel   92.703704
# 17     Water   74.151786

# %%
# Reset index for both type_2 dataframe
type_2.reset_index(inplace=True)
type_2
# Out:
#       Type 2      Attack
# 0        Bug   90.000000
# 1       Dark  109.800000
# 2     Dragon   94.444444
# 3   Electric   72.666667
# 4      Fairy   61.608696
# 5   Fighting  112.846154
# 6       Fire   81.250000
# 7     Flying   80.288660
# 8      Ghost   84.142857
# 9      Grass   74.160000
# 10    Ground   89.857143
# 11       Ice   98.000000
# 12    Normal   52.750000
# 13    Poison   67.588235
# 14   Psychic   74.696970
# 15      Rock   84.000000
# 16     Steel   92.590909
# 17     Water   70.142857

# %%
merged= pd.merge(type_1, type_2,left_on='Type 1', right_on='Type 2', suffixes=('_x', '_y'))
merged
# Out:
#       Type 1    Attack_x    Type 2    Attack_y
# 0        Bug   70.971014       Bug   90.000000
# 1       Dark   88.387097      Dark  109.800000
# 2     Dragon  112.125000    Dragon   94.444444
# 3   Electric   69.090909  Electric   72.666667
# 4      Fairy   61.529412     Fairy   61.608696
# 5   Fighting   96.777778  Fighting  112.846154
# 6       Fire   84.769231      Fire   81.250000
# 7     Flying   78.750000    Flying   80.288660
# 8      Ghost   73.781250     Ghost   84.142857
# 9      Grass   73.214286     Grass   74.160000
# 10    Ground   95.750000    Ground   89.857143
# 11       Ice   72.750000       Ice   98.000000
# 12    Normal   73.469388    Normal   52.750000
# 13    Poison   74.678571    Poison   67.588235
# 14   Psychic   71.456140   Psychic   74.696970
# 15      Rock   92.863636      Rock   84.000000
# 16     Steel   92.703704     Steel   92.590909
# 17     Water   74.151786     Water   70.142857

# %%
# Drop 'Type 1' column permanently
merged.drop(['Type 1'], axis=1, inplace=True)
merged
# Out:
#       Attack_x    Type 2    Attack_y
# 0    70.971014       Bug   90.000000
# 1    88.387097      Dark  109.800000
# 2   112.125000    Dragon   94.444444
# 3    69.090909  Electric   72.666667
# 4    61.529412     Fairy   61.608696
# 5    96.777778  Fighting  112.846154
# 6    84.769231      Fire   81.250000
# 7    78.750000    Flying   80.288660
# 8    73.781250     Ghost   84.142857
# 9    73.214286     Grass   74.160000
# 10   95.750000    Ground   89.857143
# 11   72.750000       Ice   98.000000
# 12   73.469388    Normal   52.750000
# 13   74.678571    Poison   67.588235
# 14   71.456140   Psychic   74.696970
# 15   92.863636      Rock   84.000000
# 16   92.703704     Steel   92.590909
# 17   74.151786     Water   70.142857

# %%
# Rename column
merged.rename({'Type 2':'Type'}, inplace=True, axis=1)
merged
# Out:
#       Attack_x      Type    Attack_y
# 0    70.971014       Bug   90.000000
# 1    88.387097      Dark  109.800000
# 2   112.125000    Dragon   94.444444
# 3    69.090909  Electric   72.666667
# 4    61.529412     Fairy   61.608696
# 5    96.777778  Fighting  112.846154
# 6    84.769231      Fire   81.250000
# 7    78.750000    Flying   80.288660
# 8    73.781250     Ghost   84.142857
# 9    73.214286     Grass   74.160000
# 10   95.750000    Ground   89.857143
# 11   72.750000       Ice   98.000000
# 12   73.469388    Normal   52.750000
# 13   74.678571    Poison   67.588235
# 14   71.456140   Psychic   74.696970
# 15   92.863636      Rock   84.000000
# 16   92.703704     Steel   92.590909
# 17   74.151786     Water   70.142857

# %%
# Set size of the figure
plt.figure(figsize=(14,8))
# Line plot for 'Type 1' Pokemon mean attack points
plt.plot(merged['Type'], merged['Attack_x'], color='red')

# Line plot for 'Type 2' Pokemon mean attack points
plt.plot(merged['Type'], merged['Attack_y'], color='blue')

# Setting X-axis label
plt.xlabel('Types')
# Setting Y-axis label
plt.ylabel('Mean Attack points')

# Title of the plot
plt.title('Comparison of Mean Attack Points for variants of Type 1 and Type 2')

# Setting Y-axis limit
plt.ylim((45,120))

# Legend 
plt.legend(labels=['Type 1', 'Type 2'])

# Display plot
plt.show()

# %%
#Which generation (Generation) has the highest chances of being legendary (Legendary)
Gen_group= df.groupby(['Generation', 'Legendary']).size().unstack()
Gen_group
# Out:
# Legendary   False  True
# Generation
# 1             160      6
# 2             101      5
# 3             142     18
# 4             108     13
# 5             150     15
# 6              74      8

# %%
# Plot stacked bar chart
Gen_group.plot(kind='bar', stacked=True, figsize=(15,10))

# %%
# 3.1.5 Histogram
# Visualize the distribution of `Attack` points for `Dragon` type (`Type 1`) Pokemons

# Mean 'Attack' for all Pokemons
mean_attack=df['Attack'].mean()
mean_attack
# Out:
# 79.00125

# %%
# Dataframe named dragon consisting of only "Dragon" type pokemon
dragon= df[df['Type 1']=='Dragon']
dragon
# Out:
#                      Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Dratini              Dragon       NaN   41      64       45       50       50
# Dragonair            Dragon       NaN   61      84       65       70       70
# Dragonite            Dragon    Flying   91     134       95      100      100
# Altaria              Dragon    Flying   75      70       90       70      105
# Mega Altaria         Dragon     Fairy   75     110      110      110      105
# Bagon                Dragon       NaN   45      75       60       40       30
# Shelgon              Dragon       NaN   65      95      100       60       50
# Salamence            Dragon    Flying   95     135       80      110       80
# Mega Salamence       Dragon    Flying   95     145      130      120       90
# Latias               Dragon   Psychic   80      80       90      110      130
# Mega Latias          Dragon   Psychic   80     100      120      140      150
# ...

# %%
# Mean 'Attack' for Dragon type Pokemons
mean_dragon=dragon['Attack'].mean()
mean_dragon
# Out:
# 112.125

# %%
# Histogram for Dragon type Pokemons
plt.hist(dragon['Attack'], bins=8)
plt.axvline(x=mean_attack, color='green')
plt.axvline(x=mean_dragon, color='black')

# %%
# 3.1.6 Scatter Plot
# Do electric pokemons have a correlation between their health and attack?

# Conditional filtering for 'Electric' pokemons
electric= df[df['Type 1']== 'Electric']
electric.head()
# Out:
#              Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Pikachu    Electric    NaN  35      55       40       50       50     90
# Raichu     Electric    NaN  60      90       55       90       80    110
# Magnemite  Electric  Steel  25      35       70       95       55     45
# Magneton   Electric  Steel  50      60       95      120       70     70
# Voltorb    Electric    NaN  40      30       50       55       55    100
#
#            Generation  Legendary
# Name
# Pikachu             1      False
# Raichu              1      False
# Magnemite           1      False
# Magneton            1      False
# Voltorb             1      False

# %%
# Scatter plot for 'Attack' vs 'HP'
plt.scatter(electric['HP'], electric['Attack'])
# Display plot
plt.show()

# %%
# 3.1.7 Drawing Multiple Plots
# Which type (Type 1) of Pokemons has the highest chances of being Legendary?

# Initialize figure and axes
fig,(ax_1, ax_2)= plt.subplots(1,2, figsize=(20,10))

# Stacked bar-chart representing counts
res = df.groupby(['Generation', 'Legendary']).size().unstack()
res.plot(kind='bar', stacked=True, ax=ax_1)
ax_1.set_title('Stacked bar with counts')

# Stacked bar-chart representing percentages
new_res = res.fillna(0)
new_res['Total'] = new_res[True] + new_res[False]
new_res[True] = (new_res[True] / new_res['Total']) * 100
new_res[False] = (new_res[False] / new_res['Total']) * 100
new_res.drop('Total', inplace=True, axis=1)
new_res.plot(kind='bar', stacked=True, ax=ax_2)
ax_2.set_title('Stacked bar-chart with percentages')
# Out:
# Text(0.5, 1.0, 'Stacked bar-chart with percentages')
