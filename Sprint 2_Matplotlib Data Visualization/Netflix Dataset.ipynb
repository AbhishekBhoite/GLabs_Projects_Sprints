# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
from plotly.offline import iplot, init_notebook_mode
import cufflinks

cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

# Loading data.
data = pd.read_csv(r"C:\Users\vaibh\Desktop\Python DS\Sprint 2_Matplotlib Data Visualization\netflix_titles.csv.txt")

Netflix_Data.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
# new data frame with split value columns 
new_dir = data["director"].str.split(", ", n=2, expand = True)
new_dir
# Out:
#                      0           1     2
# 0         Richard Finn  Tim Maltby  None
# 1                  NaN         NaN   NaN
# 2                  NaN         NaN   NaN
# 3                  NaN         NaN   NaN
# 4     Fernando Lebrija        None  None
# ...                ...         ...   ...
# 6229               NaN         NaN   NaN
# 6230               NaN         NaN   NaN
# 6231               NaN         NaN   NaN
# 6232               NaN         NaN   NaN
# 6233               NaN         NaN   NaN
#
# [6234 rows x 3 columns]

# %%
# making separate columns for cast member names from new data frame 
data["dir_1"]= new_dir[0] 
data["dir_2"]= new_dir[1]

# %%
new_cast = data["cast"].str.split(", ", n=4, expand = True)
new_cast
# Out:
#                      0                1                     2  \
# 0        Alan Marriott      Andrew Toth          Brian Dobson
# 1     Jandino Asporaat             None                  None
# 2         Peter Cullen  Sumalee Montano          Frank Welker
# 3         Will Friedle     Darren Criss      Constance Zimmer
# 4         Nesta Cooper       Kate Walsh  John Michael Higgins
# ...                ...              ...                   ...
# 6229      Burnie Burns    Jason Saldaña        Gustavo Sorola
# 6230        Marc Maron      Judd Hirsch           Josh Brener
# 6231               NaN              NaN                   NaN
# 6232  Daniel Radcliffe         Jon Hamm           Adam Godley
# 6233  Jennifer Aniston    Courteney Cox           Lisa Kudrow
#
#                        3                                                  4
# 0            Cole Howard  Jennifer Cameron, Jonathan Holmes, Lee Tockar,...
# ...

# %%
# making separate columns for cast member names from new data frame 
data["cast_1"]= new_cast[0] 
data["cast_2"]= new_cast[1] 
data["cast_3"]= new_cast[2]
data["cast_4"]= new_cast[3]
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
type(data['date_added'][0])
# Out:
# str

# %%
data['date_added'] = pd.to_datetime(data['date_added'])
data['year'] = data['date_added'].dt.year
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...
